# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2  
import piezoelectric_plate

piezo_plate = piezoelectric_plate.PiezoelectricPlate(create_widgets=True)
display(piezo_plate.widget_layout)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ...
