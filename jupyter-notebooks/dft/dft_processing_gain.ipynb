# %%
# %matplotlib ipympl   
# %load_ext autoreload
# %autoreload 2
import ipywidgets
import dft_processing_gain

signal = dft_processing_gain.Signal(initialise_graphs=True, create_widgets=True)
display(signal.widget.layout)
res = ipywidgets.interactive(signal.interact, 
                             n_win = signal.widget.widget['n_win'],
                             a = signal.widget.widget['a'],
                             f = signal.widget.widget['f'],                                                       
                            )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
