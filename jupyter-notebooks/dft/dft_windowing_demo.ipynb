# %%
# %matplotlib ipympl   
# %load_ext autoreload
# %autoreload 2
import ipywidgets
import dft_windowing

signal = dft_windowing.Signal(initialise_graphs=True, create_widgets=True)
display(signal.widget.layout)
res = ipywidgets.interactive(signal.interact, 
                             f_0 = signal.widget.widget['f_0'], f_1 = signal.widget.widget['f_1'],
                             a_0 = signal.widget.widget['a_0'], a_1 = signal.widget.widget['a_1'],
                             phase_0 = signal.widget.widget['phase_0'], phase_1 = signal.widget.widget['phase_1'],
                             window = signal.widget.widget['window'], n_fft = signal.widget.widget['n_fft'])
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
