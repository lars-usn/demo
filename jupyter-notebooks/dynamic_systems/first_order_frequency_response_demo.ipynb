# %% [markdown]
# # First Order System
# ## Frequency Response
#
# The frequency response $H(f)$ for a first order system is
# \begin{equation}
#     H(f) = \frac{1}{1 + j\omega\tau} = \frac{1}{1 + j\frac{f}{f_c}}
# \end{equation}
#
# The magintude $|H(f)|$ is
# \begin{equation}
#     G(f) = |H(f)| = \left| \frac{1}{1 + j\omega\tau} \right| = \sqrt{ \frac{1}{1 + (\omega \tau)^2} } = \sqrt{ \frac{1}{1 + \left( \frac{f}{f_c} \right)^2} }
# \end{equation}
#
# The phase $\phi$ of $H(f)$ is
# \begin{align}
#    \phi &= \angle \frac{1}{1 + j\omega\tau} \quad ,  & \tan \phi &= -\omega \tau = -\frac{f}{f_c}
# \end{align}
#
# The time constant for the system is $\tau$.
# The -3 dB cut-off frequency $f_c$ is given from the time constant $\tau$ as $\omega_c = \frac{1}{\tau}$ or
# \begin{equation}
#     f_c = \frac{\omega_c}{2\pi} = \frac{1}{2\pi \tau}
# \end{equation}

# %%
# %matplotlib ipympl   
# %load_ext autoreload
# %autoreload 2
import ipywidgets
import first_order_frequency_response

response = first_order_frequency_response.FrequencyResponse(initialise_graphs=True, create_widgets=True)
display(response.widget.layout)
w = ipywidgets.interactive(response.interact, tau=response.widget.widget['tau'])
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
