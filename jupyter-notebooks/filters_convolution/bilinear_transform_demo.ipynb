# %% [markdown]
# # Bilinear Transform
#
# Transform analog tranfer function $H(s)$ to the discrete $z$-domain to obtain $H(z)$.
# Ref. Lyons, 'Understanding Digital Signal Processing', 3rd ed., Ch 6.

# %%
# %matplotlib ipympl   
# %load_ext autoreload
# %autoreload 2
import bilinear_transform
import ipywidgets

transform = bilinear_transform.Transform(initialise_graphs=True, create_widgets=True)
display(transform.widget.layout)

res = ipywidgets.interactive(transform.interact, 
                             bilinear = transform.widget.widget['bilinear'],
                             sigma = transform.widget.widget['sigma'],
                             omega = transform.widget.widget['omega'])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
