# %% [markdown]
# # Matched Filter: Corralation of chirps (FM pulses)
#
# The correlation between two signals $x[n]$ and $y[n]$  defined by
# \begin{align}
#   c[k] = \sum_{n=-\infty}^{n=\infty} x[n] y[n+k]
# \end{align}
# The correlation $c[k]$ is a measure on how well the signal $y[n]$ matches $x[n]$ as function of the shift $k$.

# %%
# %matplotlib ipympl   
# %load_ext autoreload
# %autoreload 2
import chirp_correlation
import ipywidgets

chirp = chirp_correlation.Chirp()
display(chirp.widget.layout)
res = ipywidgets.interactive(chirp.interact, 
                             start_frequency = chirp.widget.widget['start_frequency_widget'],
                             end_frequency = chirp.widget.widget['end_frequency_widget'],
                             start = chirp.widget.widget['shift_widget'],
                             noise_level = chirp.widget.widget['noise_widget'],
                             magnitude = chirp.widget.widget['magnitude_widget'])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
