# %% [markdown]
# # FIR Filter Design
#
# Filter design by the Window Design Method
# Ref. Lyons, 'Understanding Digital Signal Processing', 3rd ed., Ch 5.3.1

# %%
# %matplotlib ipympl   
# %load_ext autoreload
# %autoreload 2
import fir_design
import ipywidgets

filt = fir_design.Signal(initialise_graphs=True, create_widgets=True)
display(filt.widget.layout)

res = ipywidgets.interactive(filt.interact, 
                             n_w = filt.widget.widget['n_w'],
                             window = filt.widget.widget['window'],
                             winpar = filt.widget.widget['window_parameter'])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
