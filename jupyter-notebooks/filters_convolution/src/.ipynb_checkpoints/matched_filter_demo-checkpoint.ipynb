# %% [markdown]
# # Matched Filter: Corralation of chirps (FM pulses)
#
# The correlation between two signals $x[n]$ and $y[n]$  defined by
# \begin{align}
#   c[k] = \sum_{n=-\infty}^{n=\infty} x[n] y[n+k]
# \end{align}
# The correlation $c[k]$ is a measure on how well the signal $y[n]$ matches $x[n]$ as function of the shift $k$.

# %%
# %matplotlib ipympl   
# %load_ext autoreload
# %autoreload 2
import matched_filter

chirp = matched_filter.Chirp(create_widgets=True)
display(chirp.widget_layout)
# Out:
# /home/lars-hoff/Documents/GitHub/demo/jupyter-notebooks/filters_convolution/figs/usn-logo-purple.png
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 7
#       3 get_ipython().run_line_magic('autoreload', '2')
#       4 import matched_filter
#       5
#       6 chirp = matched_filter.Chirp()
# ----> 7 display(chirp.widget_layout)
#
# AttributeError: 'Chirp' object has no attribute 'widget_layout'
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
