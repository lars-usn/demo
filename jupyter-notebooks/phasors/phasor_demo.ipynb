# %% [markdown]
# # Phasor Demo

# %%
# %matplotlib ipympl   
# %load_ext autoreload
# %autoreload 2
    
import ipywidgets
import phasor_demo

signal = phasor_demo.PhasorDemo(initialise_graphs=True, create_widgets=True)
display(signal.widget.layout)

w = ipywidgets.interactive(signal.interact,  
                           a_0=signal.widget.widget['a_0'], 
                           a_1=signal.widget.widget['a_1'], 
                           phi_0=signal.widget.widget['phi_0'], 
                           phi_1=signal.widget.widget['phi_1'])
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
